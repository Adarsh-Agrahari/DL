# %% [markdown]
# # Import Library

# %%
import numpy as np

# %% [markdown]
# ![aa.png](data:image/png;base64,...)

# %% [markdown]
# # Assign Data

# %%
revenue = np.array([[180,200,220],[24,36,40],[12,18,20]])
expenses = np.array([[80,90,100],[10,16,20],[8,10,10]])

# %% [markdown]
# # Calculate Profit (Matrix Subtraction)

# %%
profit = revenue - expenses
profit
# Out:
# array([[100, 110, 120],
#        [ 14,  20,  20],
#        [  4,   8,  10]])

# %% [markdown]
# # Assign Data

# %%
price_per_unit = np.array([1000,400,1200])
units = np.array([[30,40,50],[5,10,15],[2,5,7]])

# %% [markdown]
# # Simple Matrix Multiplication

# %%
# Numpy Broadcasting (if shape of matrix not same, it get expanded)
# price_per_unit = np.array([1000,400,1200],[1000,400,1200],[1000,400,1200])
price_per_unit*units*units
# Out:
# array([[ 900000,  640000, 3000000],
#        [  25000,   40000,  270000],
#        [   4000,   10000,   58800]])

# %% [markdown]
# # Total Sale Calculation (Dot Matrix Multiplication)

# %%
np.dot(price_per_unit,units)
# Out:
# array([34400, 50000, 64400])
